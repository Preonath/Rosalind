# %% [markdown]
# ## Fibonacci Numbers

# %%
def Fibonacci(n):
    if(n == 0):
        return 0
    elif(n == 1):
        return 1
    else:
        return(Fibonacci(n-1) + Fibonacci(n-2))
n=int(input())
print(Fibonacci(n))
# Out:
#  6
# 8

# %% [markdown]
# ## Binary Search

# %%
def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    mid = 0
    while low <= high:
        mid = (high + low) // 2
        if arr[mid] < x:
            low = mid + 1
        elif arr[mid] > x:
            high = mid - 1
        else:
            return mid
    return -1
arr = [ 2, 3, 4, 10, 40 ]
x = 10
result = binary_search(arr, x)
print(result)
# Out:
# 3

# %%
def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    mid = 0
    while low <= high:
        mid = (high + low) // 2
        if arr[mid] < x:
            low = mid + 1
        elif arr[mid] > x:
            high = mid - 1
        else:
            return mid+1
    return -1
# arr=[10,20,30, 40, 50]
# x=10
# print(binary_search(arr, k_i))
input_data=open('rosa_bins.txt')
n, m = [int(input_data.readline()) for i in range(2)]
# print(n,m)
arrr = map(int, input_data.readline().split())
arr=[]
for i in arrr:
    arr.append(i)
# print(arr)
targets = map(int, input_data.readline().split())

result = [binary_search(arr, x) for x in targets]
for i in result:
    print(i,end=" ")
# Out:
# 7094 2485 1252 6437 -1 4646 7044 738 2843 6880 1843 8797 2726 6191 3079 3251 8146 1703 2696 8486 7457 6737 3141 340 8033 1672 -1 8503 3231 835 2662 8842 -1 5234 2115 6380 2386 2970 -1 4962 7586 2198 5099 2344 2635 4393 2368 408 6281 -1 2572 230 -1 8376 1782 4907 4019 4774 2026 -1 6724 778 5224 7790 6116 3949 5295 5660 3665 4228 4593 94 -1 1194 4087 1418 4830 6172 6109 8239 2714 5916 5878 8790 1089 4810 7994 678 8123 5914 7781 -1 8256 3921 7594 8400 3053 1740 411 -1 2559 2310 2149 4936 2457 2027 -1 -1 7075 8818 4663 6597 1418 1676 5901 4707 246 -1 6180 6306 2667 2866 600 5683 6207 6846 1096 2865 8266 4805 4458 8105 4806 7809 3270 2723 5452 7937 5466 5109 957 3329 5122 2190 5044 3064 7015 7249 312 2543 -1 5830 8748 4570 1702 7758 4969 4386 2181 1059 6763 1185 790 3937 3294 4485 2112 2562 2686 -1 839 1503 6991 -1 503 2306 3976 3577 4788 446 4382 2329 4784 6717 6051 4712 1200 5036 2789 7207 7017 8381 2529 5047 7425 1874 4493 8206 5976 3695 2583 908 -1 8707 3498 7225 7956 1655 3899 4882 7
# ...

# %% [markdown]
# ## Degree Array

# %%
input_data=open('rosa_deg.txt')
n, m = map(int, input_data.readline().split())
edgeList = []

for i in range(m):
    u, v = map(int, input_data.readline().split())
    edgeList.append((u, v))
# print(edgeList) 
edges = [list() for node in range(n+1)]
# print(edges)
for edge in edgeList:
    u, v = edge
    edges[u].append(v)
    edges[v].append(u)

answer = [len(edgearr) for edgearr in edges]
for i in answer[1:]:
    print(i,end=" ")
# Out:
# 14 16 21 23 26 26 20 15 22 30 17 16 32 25 11 17 16 21 10 26 25 21 12 20 22 20 15 21 16 19 23 21 16 24 20 17 22 21 28 15 18 24 16 19 18 23 22 23 20 15 22 12 25 21 33 18 18 18 27 20 21 16 22 22 10 17 19 21 18 25 20 14 19 21 24 19 21 27 16 21 13 31 20 21 17 23 24 22 11 23 30 23 20 26 18 15 20 24 19 21 25 19 18 19 21 16 22 20 20 22 23 17 36 15 23 17 20 17 24 20 25 25 18 20 18 21 15 16 24 25 19 23 25 25 30 18 22 14 15 24 19 16 15 23 21 17 25 19 14 18 18 11 21 29 17 19 22 11 24 19 12 17 22 16 16 22 19 18 25 24 22 25 20 18 24 10 15 16 17 15 23 20 14 23 21 17 25 26 22 15 26 14 22 19 23 20 17 17 28 15 17 18 19 16 21 19 25 23 23 23 23 14 16 14 29 15 23 14 15 16 21 19 26 21 20 14 20 13 19 21 21 30 15 17 21 16 20 20 21 19 27 20 19 19 16 18 19 23 23 21 22 16 19 16 25 17 25 21 22 22 18 14 20 19 18 16 26 18 23 26 26 16 16 17 21 17 26 16 21 21 15 22 27 30 21 16 18 13 22 26 16 15 21 17 25 19 20 30 18 19 21 19 21 24 20 18 21 22 13 20 12 18 16 18 26 24 19 26 17 22 19 18 19 18 19 11 13 18 22 20 20 16 21
# ...

# %% [markdown]
# ## Insertion sort

# %%
a=[43,31,26,29,12]
n=len(a)
# print(n)

for i in range(1,n,1):
    temp=a[i]
    j=i-1
    while(j>=0 and a[j] > temp):
        a[j+1]=a[j]
        j=j-1
    a[j+1]=temp
print(a)
# Out:
# [12, 26, 29, 31, 43]

# %%
f = open("rosalind_ins.txt", "r")
p=f.readline()
n=int(p)

a=[int(x) for x in f.readline().split()]


l=[]
for i in range(1,n,1):
    temp=a[i]
    j=i-1
    x=0
    while(j>=0 and a[j] > temp):
        x+=1
        a[j+1]=a[j]
        j=j-1
    a[j+1]=temp
    l.append(x)
print(sum(l))
# Out:
# 213447

# %% [markdown]
# ## Majority Element

# %%
def max_occ(lst,x):
    count=0
    for i in lst:
        if (i==x):
            count=count+1
    return count

def findd(k,n,A):
    l_1=[]
    l_2=[]
    # d={}
    for i in range(k):
       lst=A[i]
       x=max(lst,key=lst.count)
       t=max_occ(lst,x)
       l_1.append(x)
       l_2.append((t))
       # d[x]=t
    # print(l_1)
    return(l_1,l_2)
    # print(l_2)
    # return(l_1,l_2)
    # res = dict(zip(l_1, l_2))
    # return(res)

f=open("rosalind_maj.txt", "r")
k, n = map(int, f.readline().split())
A = [line.split() for line in f]
g,f=findd(k,n,A)
# print(g,f)
res = list(zip(g,f))
l=[]
for k, v in res:
    if(v>(n/2)):
        # print(k)
        l.append(int(k))
    else:
        # print("-1")
        l.append(-1)
    # print("%s: %s" % (k, v))
# reuslt=[" ".join(str(i)) for i in l] 
# print(result)
for i in l:
    print(i,end=" ")
# Out:
# 8554 4405 6111 9011 -1 7354 8338 -1 -1 674 2464 -1 7882 -1 -1 2355 8229 9705 4258

# %% [markdown]
# ## Building a Heapsort

# %%
def heapify(arr, n, i): 
    largest = i # Initialize largest as root 
    l = 2 * i + 1 # left = 2*i + 1 
    r = 2 * i + 2 # right = 2*i + 2 

    # If left child is larger than root 
    if l < n and arr[l] > arr[largest]:
        largest = l 
  
    # If right child is larger than largest so far 
    if r < n and arr[r] > arr[largest]:
        largest = r
  
    # If largest is not root 
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr, n, largest)

def buildHeap(arr, n): 
    startIdx = n // 2 - 1
    for i in range(startIdx, -1, -1): 
        heapify(arr, n, i)

f=open("rosalind_hea.txt", "r")
n = int(f.readline())
arr = [int(i) for i in f.readline().split()]
buildHeap(arr, n)

ff = open('rosa_output.txt', 'w')
# l=[]
l=[" ".join(str(arr[i]) for i in range(n))] 
#     l.append(arr[i],end=" ")
# joined = " ".join(l)
# print(joined)
# print(l)
with open('newrna.txt','a') as answer: 
       answer.write(str(l))

# %% [markdown]
# ## Heap Sort Heapify Method

# %%
# def heapify(arr, n, i):
#     largest = i  # Initialize largest as root
#     l = 2 * i + 1     # left = 2*i + 1
#     r = 2 * i + 2     # right = 2*i + 2
  
#     # See if left child of root exists and is
#     # greater than root
#     if l < n and arr[i] < arr[l]:
#         largest = l
  
#     # See if right child of root exists and is
#     # greater than root
#     if r < n and arr[largest] < arr[r]:
#         largest = r
  
#     # Change root, if needed
#     if largest != i:
#         arr[i],arr[largest] = arr[largest],arr[i]  # swap
  
#         # Heapify the root.
#         heapify(arr, n, largest)
  
# # The main function to sort an array of given size
# def heapSort(arr):
#     n = len(arr)
  
#     # Build a maxheap.
#     # Since last parent will be at ((n//2)-1) we can start at that location.
#     for i in range(n // 2 - 1, -1, -1):
#         heapify(arr, n, i)
  
#     # One by one extract elements
#     for i in range(n-1, 0, -1):
#         arr[i], arr[0] = arr[0], arr[i]   # swap
#         heapify(arr, i, 0)
  
# # Driver code to test above
# arr = [ 12, 11, 13, 5, 6, 7]
# heapSort(arr)
# n = len(arr)
# for i in range(n):
#     print (arr[i],end= " ")

# %%
def heapify(arr, n, i):
    largest = i  # Initialize largest as root
    l = 2 * i + 1     # left = 2*i + 1
    r = 2 * i + 2     # right = 2*i + 2
  
    # See if left child of root exists and is
    # greater than root
    if l < n and arr[i] < arr[l]:
        largest = l
  
    # See if right child of root exists and is
    # greater than root
    if r < n and arr[largest] < arr[r]:
        largest = r
  
    # Change root, if needed
    if largest != i:
        arr[i],arr[largest] = arr[largest],arr[i]  # swap
  
        # Heapify the root.
        heapify(arr, n, largest)
  
# The main function to sort an array of given size
def heapSort(arr):
    n = len(arr)
  
    # Build a maxheap.
    # Since last parent will be at ((n//2)-1) we can start at that location.
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)
  
    # One by one extract elements
    for i in range(n-1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]   # swap
        heapify(arr, i, 0)
  
# Driver code to test above
f=open("rosalind_hs.txt", "r")
n=f.readline()
n=int(n)
arr = [int(i) for i in f.readline().split()]
# print(arr)
heapSort(arr)

l_hs=[" ".join(str(arr[i]) for i in range(n))] 

with open('rosalind_hs_out.txt','a') as answer: 
       answer.write(str(l_hs))

# %%
import linecache

def merge_sort(A, B):
    C = []
    i, j = 0, 0
    while i < len(A) and j < len(B):
        if A[i] <= B[j]:
            C.append(A[i])
            i += 1
        else:
            C.append(B[j])
            j += 1

    C += A[i:]
    C += B[j:]
    return C

f=open("rosalind_mer.txt", "r")
n = int(f.readline())
A = [int(i) for i in f.readline().split(' ')]
m = int(f.readline())
B = [int(i) for i in f.readline().split(' ')]
C = merge_sort(A, B)
for i in C:
    print(i, end=" ")
# Out:
# -5 2 4 10 11 12 18

# %% [markdown]
# ## Merge Sorted

# %%
def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    # Copy the remaining elements of L[], if there
    # are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    # Copy the remaining elements of R[], if there
    # are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
 
# l is for left index and r is right index of the
# sub-array of arr to be sorted
 
 
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
 
 
# Driver code to test above
arr = [12, 11, 13, 5, 6, 7]
n = len(arr)
 
mergeSort(arr, 0, n-1)
print("\n\nSorted array is")
for i in range(n):
    print(arr[i],end=" ")
# Out:
# Sorted array is
# 5 6 7 11 12 13

# %%
def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    # Copy the remaining elements of L[], if there
    # are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    # Copy the remaining elements of R[], if there
    # are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
 
# l is for left index and r is right index of the
# sub-array of arr to be sorted
 
 
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
 
 
f=open("rosalind_ms.txt", "r")
n = int(f.readline())
arr = [int(i) for i in f.readline().split(' ')]

mergeSort(arr, 0, n-1)


l=[" ".join(str(arr[i]) for i in range(n))] 
with open('ros_ms.txt','a') as answer: 
       answer.write(str(l))

# %% [markdown]
# ## Merge Two Sorted Arrays

# %%
def merge(arr, l, m, r):
    n1 = m - l + 1
    n2 = r - m
 
    # create temp arrays
    L = [0] * (n1)
    R = [0] * (n2)
 
    # Copy data to temp arrays L[] and R[]
    for i in range(0, n1):
        L[i] = arr[l + i]
 
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
 
    # Merge the temp arrays back into arr[l..r]
    i = 0     # Initial index of first subarray
    j = 0     # Initial index of second subarray
    k = l     # Initial index of merged subarray
 
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
 
    # Copy the remaining elements of L[], if there
    # are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
 
    # Copy the remaining elements of R[], if there
    # are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
 
# l is for left index and r is right index of the
# sub-array of arr to be sorted
 
 
def mergeSort(arr, l, r):
    if l < r:
 
        # Same as (l+r)//2, but avoids overflow for
        # large l and h
        m = l+(r-l)//2
 
        # Sort first and second halves
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
 
 
# Driver code to test above



f=open("rosalind_mer.txt", "r")
a = int(f.readline())
A = [int(i) for i in f.readline().split(' ')]
b = int(f.readline())
B = [int(i) for i in f.readline().split(' ')]
arr=A+B
n = a+b
mergeSort(arr, 0, n-1)

for i in range(n):
    print(arr[i],end=" ")
# Out:
# -10000 -9999 -9999 -9993 -9992 -9990 -9989 -9989 -9988 -9987 -9987 -9987 -9987 -9986 -9983 -9983 -9981 -9981 -9980 -9980 -9980 -9977 -9977 -9975 -9975 -9975 -9974 -9974 -9974 -9974 -9973 -9969 -9969 -9968 -9968 -9962 -9961 -9959 -9958 -9958 -9958 -9957 -9954 -9954 -9953 -9953 -9950 -9950 -9950 -9948 -9945 -9943 -9943 -9942 -9941 -9939 -9939 -9938 -9938 -9936 -9936 -9936 -9936 -9935 -9935 -9935 -9933 -9932 -9928 -9927 -9926 -9926 -9926 -9926 -9925 -9924 -9924 -9921 -9919 -9918 -9917 -9917 -9914 -9912 -9910 -9910 -9909 -9909 -9908 -9906 -9904 -9902 -9901 -9900 -9900 -9898 -9897 -9896 -9896 -9894 -9893 -9892 -9892 -9891 -9888 -9888 -9887 -9887 -9887 -9886 -9884 -9877 -9874 -9873 -9873 -9871 -9871 -9868 -9866 -9865 -9864 -9861 -9859 -9857 -9856 -9854 -9854 -9854 -9852 -9847 -9846 -9846 -9845 -9841 -9840 -9840 -9839 -9837 -9836 -9835 -9835 -9835 -9834 -9833 -9833 -9833 -9832 -9831 -9830 -9830 -9828 -9827 -9826 -9826 -9826 -9825 -9825 -9824 -9824 -9822 -9822 -9822 -9821 -9820 -9819 -9819 -
# ...
